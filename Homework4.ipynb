# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridBaylarzade07/DataScience/blob/main/Homework4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Intro
# Term deposits are a major source of income for a bank. A term deposit is a cash investment held at a financial institution. Your money is invested for an agreed rate of interest over a fixed amount of time, or term. The bank has various outreach plans to sell term deposits to their customers such as email marketing, advertisements, telephonic marketing, and digital marketing.
#
# Telephonic marketing campaigns still remain one of the most effective way to reach out to people. However, they require huge investment as large call centers are hired to actually execute these campaigns. Hence, it is crucial to identify the customers most likely to convert beforehand so that they can be specifically targeted via call.
#
# The data is related to direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe to a term deposit (variable y).
#
# Content
# The data is related to the direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed by the customer or not. The data folder contains two datasets:-
#
# Bank.csv: 45,211 rows and 18 columns ordered by date (from May 2008 to November 2010)
#
# Detailed Column Descriptions
# bank client data:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
# # related with the last contact of the current campaign:
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# # other attributes:
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# Missing Attribute Values: None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
print(df.shape)
df.info()
df.isnull().sum()
# Out:
# (45211, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# age          0
# job          0
# ...

# %%
#For object check the data 
for cn in df.columns:
  if(df[cn].dtype==object):
    print(df[cn].value_counts())
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# no     44396
# yes      815
# Name: default, dtype: int64
# yes    25130
# no     20081
# Name: housing, dtype: int64
# no     37967
# yes     7244
# Name: loan, dtype: int64
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
# ...

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
df=Encoder(df)
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
# ...

# %%
y = df['y'] #Output
X = df.drop('y',axis=1)
X
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
# ...

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
#  Using Decison Tree
#
# Q1) Print Confusion Matrix for Test Data How many True Positive do we have in the test data?
#
# Q2)Calculate Accuracy, Precison and Recall Score on Test Data

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
dt = DecisionTreeClassifier(criterion = 'entropy', random_state = 17)
dt.fit(X_train, y_train)
dt_pred_train = dt.predict(X_train)
dt_pred_test = dt.predict(X_test)
conf_matrix = confusion_matrix(y_true=y_test, y_pred=dt_pred_test)

#
# Print the confusion matrix using Matplotlib
#

fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

print('\n--------------\n')

print(conf_matrix)
print(sum(y_test))
print(sum(dt_pred_test))

print('\n--------------\n')

# evaluation

from sklearn.metrics import accuracy_score
print('Training Set Evaluation Accuracy score=>',accuracy_score(y_train,dt_pred_train))
# Evaluating on Test set
print('Testing Set Evaluation Accuracy score=>',accuracy_score(y_test,dt_pred_test), end='\n\n---------------\n\n')

print('Accurate Score is: ',accuracy_score(y_test,dt_pred_test), end='\n\n---------------\n\n')

from sklearn.metrics import precision_score
print('Precision: ' + str(precision_score(y_test, dt_pred_test)), end='\n\n---------------\n\n')

from sklearn.metrics import recall_score
print('Recall: ' + str(recall_score(y_test, dt_pred_test)))
# Out:
# --------------
#
# [[9254  700]
#  [ 673  676]]
# 1349
# 1376
#
# --------------
#
# Training Set Evaluation Accuracy score=> 1.0
# Testing Set Evaluation Accuracy score=> 0.8785278244713792
#
# ---------------
#
# Accurate Score is:  0.8785278244713792
#
# ---------------
#
# Precision: 0.49127906976744184
#
# ---------------
#
# Recall: 0.5011119347664937

# %% [markdown]
# we have 9254 true positive in the test data

# %% [markdown]
# Using Random Forest
#
# Q3) Print Confusion Matrix for Test Data
# How many True Positive do we have in the test data?
#
# Q4)Calculate Accuracy, Precison and Recall Score on Test Data

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion = 'entropy', random_state = 17)
rfc.fit(X_train, y_train)
rfc_pred_train = rfc.predict(X_train)
rfc_pred_test = rfc.predict(X_test)
conf_matrix = confusion_matrix(y_true=y_test, y_pred=rfc_pred_test)

#
# Print the confusion matrix using Matplotlib
#

fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()


print('\n--------------\n')

print(conf_matrix)
print(sum(y_test))
print(sum(rfc_pred_test))

print('\n--------------\n')

# evaluation

from sklearn.metrics import accuracy_score
print('Training Set Evaluation Accuracy score=>',accuracy_score(y_train,rfc_pred_train))
# Evaluating on Test set
print('Testing Set Evaluation Accuracy score=>',accuracy_score(y_test,rfc_pred_test), end='\n\n---------------\n\n')

print('Accurate Score is: ',accuracy_score(y_test,rfc_pred_test), end='\n\n---------------\n\n')

from sklearn.metrics import precision_score
print('Precision: ' + str(precision_score(y_test, rfc_pred_test)), end='\n\n---------------\n\n')

from sklearn.metrics import recall_score
print('Recall: ' + str(recall_score(y_test, rfc_pred_test)))
# Out:
# --------------
#
# [[9661  293]
#  [ 802  547]]
# 1349
# 840
#
# --------------
#
# Training Set Evaluation Accuracy score=> 1.0
# Testing Set Evaluation Accuracy score=> 0.9031230646730957
#
# ---------------
#
# Accurate Score is:  0.9031230646730957
#
# ---------------
#
# Precision: 0.6511904761904762
#
# ---------------
#
# Recall: 0.40548554484803556

# %% [markdown]
# we have 9661 true positive in the test data

# %% [markdown]
# Q5) Plot ROC Curve for Decision Tree and Random Forest
#
# Q6) Calculate AUC (Area Under Curve) Score for Decision Tree and Random Forest

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
ns_probs = [0 for _ in range(len(y_test))]
# fit a model

# predict probabilities
lr_probs = dt.predict_proba(X_test)
rr_probs = rfc.predict_proba(X_test)
# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
rr_probs = rr_probs[:, 1]



# calculate scores

# for Decision Tree
nsdt_auc = roc_auc_score(y_test, ns_probs)
lrdt_auc = roc_auc_score(y_test, lr_probs)

# for Random Forest
nsrf_auc = roc_auc_score(y_test, ns_probs)
lrrf_auc = roc_auc_score(y_test, rr_probs)



# summarize scores

# for Decision Tree
print('No Skill: ROC AUC=%.3f' % (nsdt_auc))
print('Decision Tree: ROC AUC=%.3f' % (lrdt_auc))






# calculate roc curves
nsdt_fpr, nsdt_tpr, _ = roc_curve(y_test, ns_probs)
lrdt_fpr, lrdt_tpr, _ = roc_curve(y_test, lr_probs)

# calculate roc curves
nsrf_fpr, nsrf_tpr, _ = roc_curve(y_test, ns_probs)
lrrf_fpr, lrrf_tpr, _ = roc_curve(y_test, rr_probs)





# plot the roc curve for the model
pyplot.plot(nsdt_fpr, nsdt_tpr, linestyle='--', label='No Skill')
pyplot.plot(lrdt_fpr, lrdt_tpr, marker='.', label='Decision Tree')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')

# show the legend
pyplot.legend()
# show the plot
pyplot.show()


print('\n--------------\n')

# for Random Forest
print('No Skill: ROC AUC=%.3f' % (nsrf_auc))
print('Random Forest: ROC AUC=%.3f' % (lrrf_auc))

# plot the roc curve for the model
pyplot.plot(nsrf_fpr, nsrf_tpr, linestyle='--', label='No Skill')
pyplot.plot(lrrf_fpr, lrrf_tpr, marker='.', label='Random Forest')

# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# No Skill: ROC AUC=0.500
# Decision Tree: ROC AUC=0.715
# --------------
#
# No Skill: ROC AUC=0.500
# Random Forest: ROC AUC=0.926

# %% [markdown]
# Q7) Find optimal parameters on test data using Cross validation (CV=3) technique and  Parameters set below.
#
# "max_depth": range(2, 11,2), "max_features": range(4, 16,2)
#
# a)What are the best aprameters for Random Forest and  Decison Tree
#
# b)With best parameters, calculate accuracy score for Random Forest and  Decison Tree on test Data. Compare with the accuracy result found on Q2 and Q4.
#
# Q8) Is false positive or false negative  higher cost in this case? (Hint: Read case intro in the first cell)

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

tree_params = {"max_depth": range(2, 11, 2), "max_features": range(4, 16, 2)}

tree_grid_dt = GridSearchCV(dt, tree_params, cv=3, n_jobs=-1, verbose=True)
tree_grid_rfc = GridSearchCV(rfc, tree_params, cv=3, n_jobs=-1, verbose=True)

tree_grid_dt.fit(X_train, y_train)
tree_grid_rfc.fit(X_train, y_train)

tree_grid_dt.best_params_ 

print('\n--------------\n')

tree_grid_rfc.best_params_
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
#
# --------------
# {'max_depth': 10, 'max_features': 6}

# %%
tree_grid_dt.best_score_ 
tree_grid_rfc.best_score_ 

print('Best Score for Decisoion Tree is: ', tree_grid_dt.best_score_ , end='\n\n---------------\n\n')
print('Best Score for Random Forest is: ', tree_grid_rfc.best_score_  , end='\n\n---------------\n\n')

print('Accurate Score for Decisoion Tree is: ', accuracy_score(y_test, tree_grid_dt.predict(X_test)), end='\n\n---------------\n\n')
print('Accurate Score for Random Forest is: ', accuracy_score(y_test, tree_grid_rfc.predict(X_test)) ,)
# Out:
# Best Score for Decisoion Tree is:  0.8997287122149027
#
# ---------------
#
# Best Score for Random Forest is:  0.9048602237308941
#
# ---------------
#
# Accurate Score for Decisoion Tree is:  0.8987879324073255
#
# ---------------
#
# Accurate Score for Random Forest is:  0.9028576484119261

# %% [markdown]
# Based on the Q2 and Q4, I found the accuracy score on test data as 0.8785 for Decision Tree, and 0.9031 for Random Forest. On the other side, I got the accuracy score of 0.8988 for Decision Tree, and 0.9029 for Random Forest.

# %% [markdown]
#  The classification has ability to predict that the client will subscribe to a term deposit (variable y). As a result, accuracy of the testing based of decision tree and random forest method is more than 0.89 which show that accuracy is high enough. True positive is high which indicate that outcome where the model correctly predict. False positive or False negative is lower cost in this case.
